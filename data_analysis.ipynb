# %%
import pandas as pd
import numpy as np
import pathlib

# %%
file_path = pathlib.Path("/Users/piotrkedzierski/Documents/Programowanie/Mamusia/19062026 axe txe in genome genes.xlsx")

df = pd.read_excel(file_path)

df
# Out:
#                           Application: Tecan i-control           Unnamed: 1  \
# 0                              Device: infinite 200Pro                  NaN
# 1    Firmware: V_5.40_03/24_InfiniteRX (Mar 27 2024...                  NaN
# 2                                                  NaN                  NaN
# 3                                                Date:           19.06.2026
# 4                                                Time:             09:47:22
# ..                                                 ...                  ...
# 241                                                H12                 1085
# 242                                                NaN                  NaN
# 243                                                NaN                  NaN
# 244                                                NaN                  NaN
# 245                                          End Time:  19.06.2026 15:14:42
#
#      Unnamed: 2  Unnamed: 3  \
# ...

# %%
ode = df[45:141:1]
lux = df[146:242:1]

cols = ode.columns

for col in cols[1:]:
    ode[col] = pd.to_numeric(ode[col], errors="coerce")
    lux[col] = pd.to_numeric(lux[col], errors="coerce")
# Out:
# /var/folders/fz/c2n2l12s2rxd6wkgx__1jp400000gn/T/ipykernel_56203/3031660865.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ode[col] = pd.to_numeric(ode[col], errors="coerce")
# /var/folders/fz/c2n2l12s2rxd6wkgx__1jp400000gn/T/ipykernel_56203/3031660865.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lux[col] = pd.to_numeric(lux[col], errors="coerce")

# %%
numeric_cols = ode.select_dtypes(include="number").columns

lux_by_ode = ode.copy()

lux_by_ode[numeric_cols] = lux[numeric_cols].div(ode[numeric_cols], fill_value=1)

lux_by_ode
# Out:
#     Application: Tecan i-control  Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 45                            A1    9.033424    9.025271    7.930214
# 46                            A2    9.140768    9.124088    7.917656
# 47                            A3    8.912656    9.082652    8.319468
# 48                            A4    9.337068    9.208103    8.554320
# 49                            A5    9.319665    9.337068    8.591065
# ..                           ...         ...         ...         ...
# 136                           H8    9.310987    9.363296    9.000900
# 137                           H9    9.157509    9.082652    8.795075
# 138                          H10    9.451796    9.727627    9.633911
# 139                          H11    9.478673    9.737098    9.532888
# 140                          H12    9.372071    9.661836    9.615384
#
#      Tecan i-control , 2.0.10.0  Unnamed: 5  Unnamed: 6  Unnamed: 7  \
# 45                     6.146282    4.363002    3.216468    2.754062
# ...

# %%
lux[numeric_cols].div(ode[numeric_cols], fill_value=1)
# Out:
#       Unnamed: 1   Unnamed: 2    Unnamed: 3  Tecan i-control , 2.0.10.0  \
# 45      9.033424     9.025271      7.930214                    6.146282
# 46      9.140768     9.124088      7.917656                    6.657790
# 47      8.912656     9.082652      8.319468                    6.720430
# 48      9.337068     9.208103      8.554320                    7.225433
# 49      9.319665     9.337068      8.591065                    7.246377
# ..           ...          ...           ...                         ...
# 237  6078.000000  9353.000000  20774.000000                47486.000000
# 238  6315.000000  9739.000000  20607.000000                48377.000000
# 239   966.000000  1684.000000   3356.000000                 7370.000000
# 240   984.000000  1660.000000   3285.000000                 7339.000000
# 241  1085.000000  1768.000000   3446.000000                 6989.000000
#
#        Unnamed: 5     Unnamed: 6     Unnamed: 7     Unnamed: 8     Unnamed: 9  \
# ...

# %%
ode[numeric_cols].loc(1)
